# %%
import pandas as pd 
import numpy as np
import sklearn.datasets 
import scipy.stats as ss
import matplotlib.pyplot as plt
from pathos.multiprocessing import Pool
from sklearn.ensemble import RandomForestClassifier
import pickle as pk 
from sklearn.neighbors.kde import KernelDensity
from functools import partial

# %%
with open('sigmo_cosine_corr.pickle','rb') as f:
    sigmo_cosine_corr = pk.load(f)
with open('sigmo_cosine_train.pickle','rb') as f:
    sigmo_cosine_train = pk.load(f)
with open('sigmo_permutation_corr.pickle','rb') as f:
    sigmo_permutation_corr = pk.load(f)
with open('sigmo_permutation_train.pickle','rb') as f:
    sigmo_permutation_train = pk.load(f)

# %%
with open('cosine_corr.pickle','rb') as f:
    cosine_corr = pk.load(f)
with open('cosine_train.pickle','rb') as f:
    cosine_train = pk.load(f)
with open('permutation_corr.pickle','rb') as f:
    permutation_corr = pk.load(f)
with open('permutation_train.pickle','rb') as f:
    permutation_train = pk.load(f)

# %%
fig,axis = plt.subplots(2,2,figsize=(10,10))
i = 3
j = 4
axis[0,0].plot(cosine_corr[0][i,j])
axis[0,1].plot(cosine_train[0][i,j])
axis[1,0].plot(cosine_corr[1][i,j])
axis[1,1].plot(permutation_corr[1][i,j])
'''
axis[0,0].plot(sigmo_cosine_corr[0][2,3])
axis[0,1].plot(sigmo_cosine_train[0][2,3])
axis[0,2].plot(sigmo_cosine_corr[1][2,3])
axis[0,3].plot(sigmo_permutation_corr[1][2,3])
'''
# Out:
# '\naxis[0,0].plot(sigmo_cosine_corr[0][2,3])\naxis[0,1].plot(sigmo_cosine_train[0][2,3])\naxis[0,2].plot(sigmo_cosine_corr[1][2,3])\naxis[0,3].plot(sigmo_permutation_corr[1][2,3])\n'

# %% [markdown]
# ## Linear Combination Results for Permutation & Correlation

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][0,1])
axis[1].plot(permutation_corr[1][0,1])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][0,2])
axis[1].plot(permutation_corr[1][0,2])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][0,3])
axis[1].plot(permutation_corr[1][0,3])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][0,4])
axis[1].plot(permutation_corr[1][0,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][0,5])
axis[1].plot(permutation_corr[1][0,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][0,6])
axis[1].plot(permutation_corr[1][0,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][1,2])
axis[1].plot(permutation_corr[1][1,2])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][1,3])
axis[1].plot(permutation_corr[1][1,3])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][1,4])
axis[1].plot(permutation_corr[1][1,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][1,5])
axis[1].plot(permutation_corr[1][1,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][1,6])
axis[1].plot(permutation_corr[1][1,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][2,3])
axis[1].plot(permutation_corr[1][2,3])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][2,4])
axis[1].plot(permutation_corr[1][2,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][2,5])
axis[1].plot(permutation_corr[1][2,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][2,6])
axis[1].plot(permutation_corr[1][2,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][3,4])
axis[1].plot(permutation_corr[1][3,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][3,5])
axis[1].plot(permutation_corr[1][3,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][3,6])
axis[1].plot(permutation_corr[1][3,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][4,5])
axis[1].plot(permutation_corr[1][4,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][4,6])
axis[1].plot(permutation_corr[1][4,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(permutation_corr[0][5,6])
axis[1].plot(permutation_corr[1][5,6])

# %% [markdown]
# ## Nonlinear Combination for Permutation & Correlation

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][0,1])
axis[1].plot(sigmo_permutation_corr[1][0,1])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][0,2])
axis[1].plot(sigmo_permutation_corr[1][0,2])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][0,3])
axis[1].plot(sigmo_permutation_corr[1][0,3])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][0,4])
axis[1].plot(sigmo_permutation_corr[1][0,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][0,5])
axis[1].plot(sigmo_permutation_corr[1][0,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][0,6])
axis[1].plot(sigmo_permutation_corr[1][0,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][1,2])
axis[1].plot(sigmo_permutation_corr[1][1,2])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][1,3])
axis[1].plot(sigmo_permutation_corr[1][1,3])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][1,4])
axis[1].plot(sigmo_permutation_corr[1][1,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][1,5])
axis[1].plot(sigmo_permutation_corr[1][1,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][1,6])
axis[1].plot(sigmo_permutation_corr[1][1,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][2,3])
axis[1].plot(sigmo_permutation_corr[1][2,3])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][2,4])
axis[1].plot(sigmo_permutation_corr[1][2,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][2,5])
axis[1].plot(sigmo_permutation_corr[1][2,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][2,6])
axis[1].plot(sigmo_permutation_corr[1][2,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][3,4])
axis[1].plot(sigmo_permutation_corr[1][3,4])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][3,5])
axis[1].plot(sigmo_permutation_corr[1][3,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][3,6])
axis[1].plot(sigmo_permutation_corr[1][3,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][4,5])
axis[1].plot(sigmo_permutation_corr[1][4,5])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][4,6])
axis[1].plot(sigmo_permutation_corr[1][4,6])

# %%
fig,axis = plt.subplots(1,2,figsize=(10,5))

axis[0].plot(sigmo_permutation_corr[0][5,6])
axis[1].plot(sigmo_permutation_corr[1][5,6])
